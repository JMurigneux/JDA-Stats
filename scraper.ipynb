# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import re
from bs4 import BeautifulSoup
import requests as req
import json

# %% [markdown]
# # useful tools

# %%
def sum_dict(d1,d2):
    return {k: d1.get(k, 0) + d2.get(k, 0) for k in set(d1) | set(d2)}

# %%
def subsets(s):
    sl=list(s)
    return [{sl[0],sl[1]},{sl[0],sl[2]},{sl[1],sl[2]}]

subsets({'Herdegrize', 'Oshimo', 'Terra Cogita'})
# Out:
# [{'Oshimo', 'Terra Cogita'},
#  {'Herdegrize', 'Terra Cogita'},
#  {'Herdegrize', 'Oshimo'}]

# %%
def dict_count_val_over(dic,limit):
    count=0
    for v in dic.values():
        if v>limit:
            count+=1
    return count

# %%
def dict_barh(dic,title="michel",sort=False):
    
    if sort:
        dic_s=dict(sorted(dic.items(), key=lambda item: item[1]))

    else:
        dic_s=dic
    compp=dic_s.items()
    x, y = zip(*compp)   
    # print(x,y)
    offset_text=(max(y)/60)

    fig, ax=plt.subplots(figsize=(10,5),facecolor='#7B7826')
    ax.set_facecolor("#B69E44")

    x_strip=[k.replace("{","").replace("}","").replace('"',"").replace("'","") for k in x]
    ax.barh(x_strip, y,facecolor='#231D0F')
    for i in range(len(x)):
        ax.text( y[i]+offset_text,i, y[i], ha='left',va="center",color='black')

    if title!="michel":
        ax.set_title(title)
    plt.tight_layout()
    plt.savefig("graphs_tournament_phase/"+title+'.png')
    
    plt.show()

# %%
#fonction qui sert à filtrer et enlever les keys dont la valeur est en dessous de 3

def filterTheDict(dictObj, callback):
    newDict = dict()
    # Iterate over all the items in dictionary
    for (key, value) in dictObj.items():
        # Check if item satisfies the given condition then add to new dict
        if callback((key, value)):
            newDict[key] = value
    return newDict

# %%
def duo_to_list(s):
    spl=re.findall('[a-z]+',s)
    return spl

duo_to_list("{'eniripsa', 'iop'}")
# Out:
# ['eniripsa', 'iop']

# %% [markdown]
# # KTA team scraper

# %%
url= "https://ktarena.com/fr/227-the-abyss-joust/participants"
page= req.get(url)
soup=BeautifulSoup(page.content,"html.parser")

big_element=soup.find_all('script')

# %%
tab_raw=big_element[11]
tab_str=str(tab_raw.string)
print(tab_str[37:])
n=len(tab_str)
print(tab_str[n-100:n-21])

trim=tab_str[37:n-21]
d=json.loads(trim)
# Out:
# [{"name":"\u003Ca href=\u0027equipe\/7667\u0027\u003EChartered\u003C\/a\u003E","players":"\u003Cdiv class=\\\u0022players\\\u0022\u003E\u003Ca href=\\\u0022\/fr\/joueur\/37948\\\u0022 title=\\\u0022Konosey\\\u0022\u003E\u003Cimg src=\\\u0022\/assets\/img\/players\/37000\/37900\/37948\/logo.jpg?1695643007\\\u0022 alt=\\\u0022Konosey\\\u0022\/\u003E\u003C\/a\u003E\u003Ca href=\\\u0022\/fr\/joueur\/37665\\\u0022 title=\\\u0022Heal-wing\\\u0022\u003E\u003Cimg src=\\\u0022\/assets\/img\/players\/0\/0\/0\/logo.jpg?1662398020\\\u0022 alt=\\\u0022Heal-wing\\\u0022\/\u003E\u003C\/a\u003E\u003Ca href=\\\u0022\/fr\/joueur\/37312\\\u0022 title=\\\u0022Whith-Haze\\\u0022\u003E\u003Cimg src=\\\u0022\/assets\/img\/players\/0\/0\/0\/logo.jp
u0022\/fr\/joueur\/38110\\\u0022 title=\\\u0022Vandettale\\\u0022\u003E\u003Cimg src=\\\u0022\/assets\/img\/players\/0\/0\/0\/logo.jpg?1662398020\\\u0022 alt=\\\u0022Vandettale\\\u0022\/\u003E\u003C\/a\u003E\u003C\/div\u003E","classes":"\u003Cdiv style=\u0027display: inline-block; overflow:hidden\u0027\u003E\u003Cimg class=\u0027\u0027 alt=\u0027eniripsa\u0027 title=\u0027eniripsa\u0027 src=\u0027\/assets\/img\/classes\/4.png\u0027\/\u003E\u003Cimg class=\u0027\u0027 alt=\u0027steamer\u0027 title=\u0027steamer\u0027 src=\u0027\/assets\/img\/classes\/15.png\u0027\/\u003E\u003Cimg class=\u0027\u0027 alt=\u0027iop\u0027 title=\u0027iop\u0027 src=\u0027\/assets\/img\/classes\/8.png\u0027\/\u003E\u003C\/div\u003E"},{"name":"\u003Ca href=\u0027equipe\/7798\u0027\u003 ...
#
# 0027 src=\u0027\/assets\/img\/classes\/10.png\u0027\/\u003E\u003C\/div\u003E"}]

# %%
d[0]
# Out:
# {'name': "<a href='equipe/7667'>Chartered</a>",
#  'players': '<div class=\\"players\\"><a href=\\"/fr/joueur/37948\\" title=\\"Konosey\\"><img src=\\"/assets/img/players/37000/37900/37948/logo.jpg?1695643007\\" alt=\\"Konosey\\"/></a><a href=\\"/fr/joueur/37665\\" title=\\"Heal-wing\\"><img src=\\"/assets/img/players/0/0/0/logo.jpg?1662398020\\" alt=\\"Heal-wing\\"/></a><a href=\\"/fr/joueur/37312\\" title=\\"Whith-Haze\\"><img src=\\"/assets/img/players/0/0/0/logo.jpg?1662398020\\" alt=\\"Whith-Haze\\"/></a></div>',
#  'classes': "<div style='display: inline-block; overflow:hidden'><img class='' alt='xelor' title='xelor' src='/assets/img/classes/16.png'/><img class='' alt='eniripsa' title='eniripsa' src='/assets/img/classes/4.png'/><img class='' alt='iop' title='iop' src='/assets/img/classes/8.png'/></div>"}

# %%
print(d[0]["players"])

def extract_play(s):
    spl=s.split('title=\\"')

    fi=spl[1].split('\\\"')[0]
    sec=spl[2].split('\\\"')[0]
    ter=spl[3].split('\\\"')[0]

    spl2=s.split('href=\\"/fr/joueur/')
    fi_id=spl2[1].split('\\"')[0]
    sec_id=spl2[2].split('\\"')[0]
    ter_id=spl2[3].split('\\"')[0]
    return fi,sec,ter,fi_id,sec_id,ter_id

extract_play(d[0]["players"])
# Out:
# <div class=\"players\"><a href=\"/fr/joueur/37948\" title=\"Konosey\"><img src=\"/assets/img/players/37000/37900/37948/logo.jpg?1695643007\" alt=\"Konosey\"/></a><a href=\"/fr/joueur/37665\" title=\"Heal-wing\"><img src=\"/assets/img/players/0/0/0/logo.jpg?1662398020\" alt=\"Heal-wing\"/></a><a href=\"/fr/joueur/37312\" title=\"Whith-Haze\"><img src=\"/assets/img/players/0/0/0/logo.jpg?1662398020\" alt=\"Whith-Haze\"/></a></div>
# ('Konosey', 'Heal-wing', 'Whith-Haze', '37948', '37665', '37312')

# %%
print(d[0]["name"])

def extract_team(s):
    # id_team=int(re.findall("[0-9]+",s)[0])
    
    name=s.split("'>")[1][:-4]

    return name#,id_team


extract_team(d[0]["name"])
# Out:
# <a href='equipe/7667'>Chartered</a>
# 'Chartered'

# %%
print(d[0]["classes"])

def extract_classes(s):
    spl=s.split("title='")[1:]
    spl2=tuple([ ss.split("' ")[0]  for ss in spl])
    # sec=spl[1][:-4]
    # fi=spl[0].split('"')[-1]
    return spl2

extract_classes(d[0]["classes"])
# Out:
# <div style='display: inline-block; overflow:hidden'><img class='' alt='xelor' title='xelor' src='/assets/img/classes/16.png'/><img class='' alt='eniripsa' title='eniripsa' src='/assets/img/classes/4.png'/><img class='' alt='iop' title='iop' src='/assets/img/classes/8.png'/></div>
# ('xelor', 'eniripsa', 'iop')

# %%
p1=[]
p2=[]
p3=[]

p1_id=[]
p2_id=[]
p3_id=[]

c1=[]
c2=[]
c3=[]

team=[]

for dic in d:
    (tp1,tp2,tp3,tp1_id,tp2_id,tp3_id)=extract_play(dic["players"])
    p1.append(tp1)
    p2.append(tp2)
    p3.append(tp3)

    p1_id.append(tp1_id)
    p2_id.append(tp2_id)
    p3_id.append(tp3_id)

    (tc1,tc2,tc3)=extract_classes(dic["classes"])
    c1.append(tc1)
    c2.append(tc2)
    c3.append(tc3)
    
    team.append(extract_team(dic["name"]))

# %%
df=pd.DataFrame()
df["equipes"]=team

df["J1"]=p1
df["J2"]=p2
df["J3"]=p3

df["ID_J1"]=p1_id
df["ID_J2"]=p2_id
df["ID_J3"]=p3_id

df["classe_J1"]=c1
df["classe_J2"]=c2
df["classe_J3"]=c3

df=df.set_index("equipes")
df
# Out:
#                                 J1              J2             J3  ID_J1  \
# equipes
# Chartered                  Konosey       Heal-wing     Whith-Haze  37948
# Fox-ez                     Cala-ez        Qenzz-ez         Beg-ez  37342
# Askip                  Bondi-Beach      Golden-Ill     Vandettale  37636
# Hide your poney           Hoodwolf     Wanshot-Eca         Wamimi  38429
# PANTHEON           Deos-Sociopathe        Mercuure  Eka-tastrophe  37292
# ...                            ...             ...            ...    ...
# Luxury                  Darkempart        Darkoufr         Amouiz  38329
# Ogre battle                 Forcas  Jven-Pescadora   Pklordkiller  37510
# Blitzkrieg Brutas          xxcriis         Steissy          Gofal  37397
# La Gestapo                    Znup     Rudolf-heez       Bestialx  37147
# Radioactive Squad           Naarqz         Draelyk     Sociologie  38251
#
#                    ID_J2  ID_J3 classe_J1 classe_J2 classe_J3
# equipes
# Chartered          37665  37312     xelor  eniripsa       iop
# Fox-ez             37638  37324   enutrof  eniripsa       iop
# Askip              38370  38110  eniripsa   steamer       iop
# Hide your poney    38442  38446  osamodas   ecaflip      feca
# PANTHEON           37456  37457     zobal   steamer     xelor
# ...                  ...    ...       ...       ...       ...
# Luxury             38346  38373     xelor       iop       cra
# Ogre battle        37500  37422       iop   steamer      sram
# Blitzkrieg Brutas  37415  37492   ecaflip   steamer      feca
# La Gestapo         37274  37246  osamodas   pandawa       iop
# Radioactive Squad  38268  38283      feca   ecaflip   pandawa
#
# [182 rows x 9 columns]

# %%
df.loc["IMPACT_",:]
# Out:
# J1             Hygura
# J2            Lazycat
# J3               Warp
# ID_J1           37249
# ID_J2           37300
# ID_J3           37245
# classe_J1    sacrieur
# classe_J2     ecaflip
# classe_J3    osamodas
# Name: IMPACT_, dtype: object

# %% [markdown]
# Parse les id de joueurs pour récup les serveurs annoncés sur le site KTA

# %%
def get_and_find_serv(id):
    url="https://ktarena.com/fr/joueur/"+str(id)
    page= req.get(url)
    soup=BeautifulSoup(page.content,"html.parser")

    big_element=soup.find_all('div',class_="name")
    return big_element[0].string

get_and_find_serv(37245) #id warp = 37245
# Out:
# 'Herdegrize'

# %%
df["serveur_J1"]=df["ID_J1"].apply(get_and_find_serv)
df["serveur_J2"]=df["ID_J2"].apply(get_and_find_serv)
df["serveur_J3"]=df["ID_J3"].apply(get_and_find_serv)
df
# Out:
#                                 J1              J2             J3  ID_J1  \
# equipes
# Chartered                  Konosey       Heal-wing     Whith-Haze  37948
# Fox-ez                     Cala-ez        Qenzz-ez         Beg-ez  37342
# Askip                  Bondi-Beach      Golden-Ill     Vandettale  37636
# Hide your poney           Hoodwolf     Wanshot-Eca         Wamimi  38429
# PANTHEON           Deos-Sociopathe        Mercuure  Eka-tastrophe  37292
# ...                            ...             ...            ...    ...
# Luxury                  Darkempart        Darkoufr         Amouiz  38329
# Ogre battle                 Forcas  Jven-Pescadora   Pklordkiller  37510
# Blitzkrieg Brutas          xxcriis         Steissy          Gofal  37397
# La Gestapo                    Znup     Rudolf-heez       Bestialx  37147
# Radioactive Squad           Naarqz         Draelyk     Sociologie  38251
#
#                    ID_J2  ID_J3 classe_J1 classe_J2 classe_J3  \
# equipes
# Chartered          37665  37312     xelor  eniripsa       iop
# Fox-ez             37638  37324   enutrof  eniripsa       iop
# Askip              38370  38110  eniripsa   steamer       iop
# Hide your poney    38442  38446  osamodas   ecaflip      feca
# PANTHEON           37456  37457     zobal   steamer     xelor
# ...                  ...    ...       ...       ...       ...
# Luxury             38346  38373     xelor       iop       cra
# Ogre battle        37500  37422       iop   steamer      sram
# Blitzkrieg Brutas  37415  37492   ecaflip   steamer      feca
# La Gestapo         37274  37246  osamodas   pandawa       iop
# Radioactive Squad  38268  38283      feca   ecaflip   pandawa
#
#                          serveur_J1    serveur_J2    serveur_J3
# equipes
# Chartered                     Dodge         Dodge         Dodge
# Fox-ez                   Non défini  Terra Cogita  Terra Cogita
# Askip                    Herdegrize    Non défini    Herdegrize
# Hide your poney              Oshimo        Oshimo    Non défini
# PANTHEON               Terra Cogita  Terra Cogita  Terra Cogita
# ...                             ...           ...           ...
# Luxury                   Herdegrize    Herdegrize    Herdegrize
# Ogre battle        Touch tournament        Brutas    Non défini
# Blitzkrieg Brutas        Non défini    Non défini    Non défini
# La Gestapo                   Brutas        Brutas        Brutas
# Radioactive Squad      Terra Cogita  Terra Cogita  Terra Cogita
#
# [182 rows x 12 columns]

# %%
print((df["serveur_J1"].unique()))
print((df["serveur_J2"].unique()))
print((df["serveur_J3"].unique()))
# Out:
# ['Dodge' 'Non défini' 'Herdegrize' 'Oshimo' 'Terra Cogita' 'Grandapan'
#  'Brutas' 'Touch tournament' 'Hell Mina' 'Draconiros' 'Tal Kasha']
# ['Dodge' 'Terra Cogita' 'Non défini' 'Oshimo' 'Touch tournament'
#  'Herdegrize' 'Brutas' 'Grandapan' 'Tal Kasha']
# ['Dodge' 'Terra Cogita' 'Herdegrize' 'Non défini' 'Oshimo' 'Brutas'
#  'Touch tournament' 'Grandapan' 'Tylezia' 'Tal Kasha']

# %%
def clean_serveurs(serv):
    if serv=='Touch tournament':
        return 'Non défini'
    elif serv not in ['Dodge','Herdegrize','Terra Cogita','Brutas','Grandapan','Oshimo','Non défini']:
        return 'Dofus PC'
    else:
        return serv

# %%
df["serveur_J1_cleaned"]=df["serveur_J1"].apply(clean_serveurs)
df["serveur_J2_cleaned"]=df["serveur_J2"].apply(clean_serveurs)
df["serveur_J3_cleaned"]=df["serveur_J3"].apply(clean_serveurs)

print((df["serveur_J1_cleaned"].unique()))
print((df["serveur_J2_cleaned"].unique()))
print((df["serveur_J3_cleaned"].unique()))
# Out:
# ['Dodge' 'Non défini' 'Herdegrize' 'Oshimo' 'Terra Cogita' 'Grandapan'
#  'Brutas' 'Dofus PC']
# ['Dodge' 'Terra Cogita' 'Non défini' 'Oshimo' 'Herdegrize' 'Brutas'
#  'Grandapan' 'Dofus PC']
# ['Dodge' 'Terra Cogita' 'Herdegrize' 'Non défini' 'Oshimo' 'Brutas'
#  'Grandapan' 'Dofus PC']

# %%
s1=df.groupby(by=["serveur_J1_cleaned"]).count()["J1"].to_dict()
s2=df.groupby(by=["serveur_J2_cleaned"]).count()["J1"].to_dict()
s3=df.groupby(by=["serveur_J3_cleaned"]).count()["J1"].to_dict()


s4=sum_dict(sum_dict(s1,s2),s3)
s4
# Out:
# {'Dodge': 12,
#  'Terra Cogita': 82,
#  'Brutas': 90,
#  'Oshimo': 61,
#  'Grandapan': 18,
#  'Dofus PC': 6,
#  'Non défini': 157,
#  'Herdegrize': 120}

# %%
def team_serv_definition(row):
    # Extract values from the row
    serveur_J1 = row['serveur_J1_cleaned']
    serveur_J2 = row['serveur_J2_cleaned']
    serveur_J3 = row['serveur_J3_cleaned']

    serveur_set={serveur_J1,serveur_J2,serveur_J3}
    if 'Non défini' in serveur_set:
        serveur_set.remove('Non défini')
    
    if len(serveur_set)>1:
        if 'Dofus PC' in serveur_set:
            serveur_set.remove('Dofus PC')
            if len(serveur_set)==1:
                return serveur_set.pop()
            else:
                return "Interserveur"     
        return "Interserveur"
    elif len(serveur_set)==1:
        return serveur_set.pop()
    else:
        return 'Non défini'
# Apply the custom function to create the fourth column
df['serveur_team'] = df.apply(team_serv_definition, axis=1)

# %%
df.to_excel("team_JDA_tournament_phase.xlsx")

# %%
df.loc["Abracadabra",:]
# Out:
# J1                        Pokker
# J2                    Senti-ment
# J3                     Payko-Sky
# ID_J1                      38397
# ID_J2                      38405
# ID_J3                      38411
# classe_J1                ecaflip
# classe_J2                   feca
# classe_J3                pandawa
# serveur_J1            Herdegrize
# serveur_J2            Herdegrize
# serveur_J3            Herdegrize
# serveur_J1_cleaned    Herdegrize
# serveur_J2_cleaned    Herdegrize
# serveur_J3_cleaned    Herdegrize
# serveur_team          Herdegrize
# Name: Abracadabra, dtype: object

# %% [markdown]
# # KTA matchs scraper

# %%
url= "https://ktarena.com/fr/227-the-abyss-joust/matchs/471"
url_r1="https://ktarena.com/en/227-the-abyss-joust/matches/2002"
url_r2="https://ktarena.com/en/227-the-abyss-joust/matches/2003"
page= req.get(url_r1)
soup=BeautifulSoup(page.content,"html.parser")

big_element=soup.find_all('script')

# %%
tab_raw=big_element[-1]
tab_str=str(tab_raw.string)
# print(tab_str)
trim=tab_str[29:-830]
n=len(trim)
print(trim[:100])
print(trim[n-100:])

d=json.loads(trim)
matches_raw=[didi["html"] for didi in d]
no_score=matches_raw[0]
w_score=matches_raw[-1]
# Out:
# [{"html":"\u003Cdiv class=\\\u0022match\\\u0022\u003E\u003Cdiv class=\\\u0022head\\\u0022\u003E\u003
# C\/div\u003E\u003C\/div\u003E\u003C\/div\u003E\u003C\/div\u003E\u003C\/div\u003E\u003C\/div\u003E"}]

# %%
def extract_match_not_played(s):
    spl=s.split('title=\\"')
    team1=spl[1].split(" - ")[0]
    team2=spl[3].split(" - ")[0]

    if team1=="No Pain":
        team1="No Pain - No Gain"
    if team2=="No Pain":
        team2="No Pain - No Gain"
    return team1,team2,"en_attente"

# %%
def extract_match_played(s):
    spl=s.split('title=\\"')
    # print(spl)
    team1=spl[1].split(" - ")[0]
    team2=spl[3].split(" - ")[0]

    if len(re.findall("score win",spl[1]))>0:
        team_win=team1
    else:
        team_win=team2

    if team1=="No Pain":
        team1="No Pain - No Gain"
    if team2=="No Pain":
        team2="No Pain - No Gain"
        
    return team1,team2,team_win

# %%
team_left=[]
team_right=[]
vainqueur=[]

for s in matches_raw:

    if len(re.findall("score win",s))==0: #match en attente d'etre joué
        temp_left,temp_right,temp_win=extract_match_not_played(s)
    else: #match joué
        temp_left,temp_right,temp_win=extract_match_played(s)
    
    team_left.append(temp_left)
    team_right.append(temp_right)
    vainqueur.append(temp_win)

# %%
ronde=pd.DataFrame()
ronde["equipe A"]=team_left
ronde["equipe B"]=team_right
ronde["vainqueur"]=vainqueur

# %%
ronde
# Out:
#                         equipe A           equipe B          vainqueur
# 0                      Chartered         Aminakoyim          Chartered
# 1                 Veni-Vidi-Vici          Le retour          Le retour
# 2                         Fox-ez  cripis mancoticks             Fox-ez
# 3                          Askip           Zoo Name              Askip
# 4                Hide your poney            Dark So    Hide your poney
# ..                           ...                ...                ...
# 86                Assassins Crew            SAO-TWO     Assassins Crew
# 87       LO MAS FRESA DEL PEDAZO          Sambayoyo          Sambayoyo
# 88               Marche ou creve             Puenta    Marche ou creve
# 89             Rakatapumchinchin          guardians  Rakatapumchinchin
# 90  Mes propositions deux-points        Abracadabra        Abracadabra
#
# [91 rows x 3 columns]

# %%
ronde.to_excel("resultats_ronde1.xlsx")

# %% [markdown]
# # Add results to team df

# %%
df_team=pd.read_excel("team_JDA_tournament_phase.xlsx",index_col="equipes")

# %%
df_team["win"]=[0]*df_team.shape[0]
df_team["lose"]=[0]*df_team.shape[0]

# %%
for idx,row in ronde1.iterrows():
    if row["vainqueur"]==row["equipe A"]:
        df_team.loc[row["equipe A"],"win"]+=1
        df_team.loc[row["equipe B"],'lose']+=1
    else:
        df_team.loc[row["equipe A"],"lose"]+=1
        df_team.loc[row["equipe B"],'win']+=1

# %%
df_team.to_excel("team_JDA_tournament_phase_r1.xlsx")

# %%
df_team
